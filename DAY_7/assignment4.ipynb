# %%
squared = [i*i for i in range(11)]
squared
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
even = [i for i in range(1,11) if i & 1 ==0]
even
# Out:
# [2, 4, 6, 8, 10]

# %%
cube = {i:i*i*i for i in range(1,6)}
cube
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125}

# %%
vowels = ( i for i in "comprehensions are powerful" if i in "aeiouAEIOU")
list(vowels)
# Out:
# ['o', 'e', 'e', 'i', 'o', 'a', 'e', 'o', 'e', 'u']

# %%
dic ={'Alice':85,"Bob":78,"Charlie":92,"David":63}
lis={i:dic[i] for i in dic if dic[i]>80}
lis
# Out:
# {'Alice': 85, 'Charlie': 92}

# %%
lis2 = {i:j for i,j in dic.items() if j>80}
lis2
# Out:
# {'Alice': 85, 'Charlie': 92}

# %%
lis1 =[1,2,3]
lis2=[4,5,6]

out = [(i,j) for i in lis1 for j in lis2 if lis1.index(i) == lis2.index(j)]
out
# Out:
# [(1, 4), (2, 5), (3, 6)]

# %%
l = [1,2,3,4,5]
for [i,j] in l :
    print(f"{i}:{j}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 l = [1,2,3,4,5]
# ----> 2 for [i,j] in l:
#       3     print(f"{i}:{j}")
#
# TypeError: cannot unpack non-iterable int object

# %%
lis = [1,2,3,4,5,1,2,3]
out = [f"({curr},{nxt}) = " "l" if curr > nxt else f"({curr},{nxt}) = " "h" for curr, nxt in zip(lis,lis[1:])]
list(out)
# Out:
# ['(1,2) = h',
#  '(2,3) = h',
#  '(3,4) = h',
#  '(4,5) = h',
#  '(5,1) = l',
#  '(1,2) = h',
#  '(2,3) = h']

# %%
vowels = "aeiou"
numbers = [1,2,3,4,5]
numbers1 = [1,5,6,15,21]

dic1 = {i:j for i,j in zip(vowels,numbers1)}
dic1
# Out:
# {'a': 1, 'e': 5, 'i': 6, 'o': 15, 'u': 21}

# %%
dic2 = {j:i for i,j in enumerate(vowels,1)}
dic2
# Out:
# {'a': 1, 'e': 2, 'i': 3, 'o': 4, 'u': 5}

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
dict.fromkeys("aeiou",[1,2,3,4,5])
# Out:
# {'a': [1, 2, 3, 4, 5],
#  'e': [1, 2, 3, 4, 5],
#  'i': [1, 2, 3, 4, 5],
#  'o': [1, 2, 3, 4, 5],
#  'u': [1, 2, 3, 4, 5]}
